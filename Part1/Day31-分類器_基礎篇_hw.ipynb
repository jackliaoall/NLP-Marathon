# %%
# !python --version
# Out:
# Python 3.6.9

# %%
# !pip install -q -U pip
# !pip install -q numpy
# !pip install -q pandas
# !pip install -q ckiptagger
# !pip install -q tqdm
# !pip install -q tensorflow==1.14.0
# !pip install -q ipywidgets
# Out:
#      |████████████████████████████████| 1.5MB 9.0MB/s
#      |████████████████████████████████| 109.2 MB 2.4 kB/s
#      |████████████████████████████████| 50 kB 8.2 MB/s
#      |████████████████████████████████| 3.1 MB 68.1 MB/s
#      |████████████████████████████████| 488 kB 56.7 MB/s

# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                            title
# 0         0    體育         亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育        9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育             如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育            超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育          騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# ...     ...   ...                              ...
# 1795   1795    遊戲  LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲            穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲          騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                   LOL你不知道的黑科技打法！
# 1799   1799    遊戲                 遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
# !wget https://cumatrixfile.cupoy.com/00000174538BF9AC000000076375706F795F72656C656173654349/marathon/data.7z?t=1604024676626
# Out:
# --2020-12-13 09:46:20--  https://cumatrixfile.cupoy.com/00000174538BF9AC000000076375706F795F72656C656173654349/marathon/data.7z?t=1604024676626
# Resolving cumatrixfile.cupoy.com (cumatrixfile.cupoy.com)... 99.86.35.72, 99.86.35.78, 99.86.35.19, ...
# Connecting to cumatrixfile.cupoy.com (cumatrixfile.cupoy.com)|99.86.35.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3659454979 (3.4G) [application/octet-stream]
# Saving to: ‘data.7z?t=1604024676626’
#
# data.7z?t=160402467 100%[===================>]   3.41G  19.1MB/s    in 2m 57s
#
# 2020-12-13 09:49:17 (19.7 MB/s) - ‘data.7z?t=1604024676626’ saved [3659454979/3659454979]

# %%
# !sudo apt update && sudo apt install --assume-yes p7zip-full
!7z x data.7z
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 36 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 3659454979 bytes (3490 MiB)
#
# Extracting archive: data.7z
# --
# Path = data.7z
# Type = 7z
# Physical Size = 3659454979
# Headers Size = 691
# Method = LZMA2:26
# Solid = +
# Blocks = 2
#
# Everything is Ok
#
# Folders: 6
# Files: 20
# Size:       4445213888
# Compressed: 3659454979

# %%
ws = WS('./D07data/')
pos = POS('./D07data/')
# Out:
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e2f846d68>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e2f846d68>>: AttributeError: module 'gast' has no attribute 'Num'
# Exception ignored in: <bound method WS.__del__ of <ckiptagger.api.WS object at 0x7f3e2f8462e8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ckiptagger/api.py", line 65, in __del__
#     self.model.sess.close()
# AttributeError: 'WS' object has no attribute 'model'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e2edc86a0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e2edc86a0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e2edc8f98>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e2edc8f98>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e2edc8f60>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e2edc8f60>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f3e2ee035c0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f3e2ee035c0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e18e60780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e18e60780>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e2d3947b8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e2d3947b8>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e18e60ef0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e18e60ef0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e18df9240>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f3e18df9240>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f3e2d235b00>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f3e2d235b00>>: AssertionError: Bad argument number for Name: 3, expecting 4

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    # YOUR CODE HERE
    word_s = ws([title])
    word_p = pos(word_s)
    # END YOUR CODE
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    # YOUR CODE HERE
    word_s = ws([title])
    word_p = pos(word_s)
    # END YOUR CODE
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
# YOUR CODE HERE
n = 0
for index in train_title_cuts:
    for word, flag in train_title_cuts[index]:
        if word in word2index:
            continue
        word2index[word] = n 
        index2word[n] = word
        n += 1
# END YOUR CODE

# %%
word2index['溫暖']
# Out:
# 1520

# %%
index2word[1520]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index):
    # YOUR CODE HERE
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index:
            vector[word2index[word]] += 1
    # END YOUR CODE
    return vector

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['卡拉黑', '羅傑斯', '阿里巴巴', '比格利亞', '弗格森', '慧商', '·瞻', 'U23', '劉詩雯', '意大利杯', '阿迪薩亞', '凱爾特', '拜仁續', '泰倫', '劉熾平', '林美景', '樸泰夏', '傑尼亞', '黃紫昌', '小強', '李嘉誠', '神帥', '卡帥', '白起', '切沃', '賞月夜', '王者榮', '德帥', '上港', '唐培科', '朱嘯虎', '泰倫盧', '奧恰洛夫', '山東隊', '高曉松', '刷安徒恩', '沃爾瑪', '泰森', '娜迦王海伯倫', '老詹', '陰陽師', '曼薩諾', '余則成', '里坦克', '約翰塞納', '傑森', '武當', '余小C', '微星', '老馬', '綠心', '萬孚', '嬴政', '亞特拉斯賽', '伏爾加格勒', '梁建章', '金秀瑤族', '男乒', '高通', '尤文', '權健', '大神', '科爾', '里皮', '美年達', '浦發', '璞麗', '費基爾', '皇馬', '德羅巴', '耀里', '鍾馗', '郭春林', '馬克思', '維特爾', '李白界', '猛', '金英權', 'J羅', '美宇', '波爾', '羅森', '勒布朗', '火箭隊', '藍星', '峽谷里', '韓信', '雀巢', '拳皇', '勇士隊', '李盈瑩', '朗多', '張本智和', '埃爾克森', '杜蘭特', '李謹詺', '安琪拉', '騎士隊', '劉歡', '安永']
# =======================
# VC : ['渲染', '等', '支持', '花費', '助推', '拍', '研發', '發推', '防治', '賒', '採', '領導', '影響', '膜拜', '弄', '穿', '對付', '做出', '保駕', '伴隨', '扔', '看完', '產出', '造就', '打磨', '評價', '通過', '等到', '添新', '徵召', '貢獻', '防', '出口', '攀爬', '評論', '環遊', '單殺', '燒烤', '投', '包車', '收取', '開', '控制', '吸', '召開', '調整', '進口', '打響', '繼承', '扔上', '考察', '套種', '屠殺', '派出', '學習', '喜出', '挖', '大賺', '擺出', '融入', '領', '開復', '制定', '醫療', '點贊', '破除', '吃好', '輸出', '搬進', '陪', '裝', '命懸', '隱藏', '管理', '解說', '脫離', '避開', '引進', '洩露', '包裝', '蓋', '絕殺', '冒充', '認養', '創新', '學到', '養活', '攜驅', '抓住', '化解', '炒', '投身', '擇', '止損', '攻略', '外掛', '拿到', '打飛', '掛', '投放']
# =======================
# Na : ['飛機票', '最為難', '序', '大海', '驚夢', '峰', '軸', '部位', '秧田', '疾病', '絕壁', '歐冠席', '大黃魚', '青玉薩', '英雄榜', '濾鏡', '光子', '定制商', '臍橙', '含金量', '消息', '生涯', '主教練', '粉絲', '收付款', '獨生子女', '板', '茅台酒', '高端', '年薪', '現象', '稅利好', '田徑', '系列', '情侶', '做法', '害處', '戰隊', '田水', '業務', '低保', '花迪', '一線', '衣服', '發酵劑', '信號', '出鏡率', '勝地', '詛咒', '鈣', '們', '成冠軍', '本金', '神', '財富', '鵜鶘', '革命性', '位置', '賽', '裁判', 'F組', '油菜花', '收益率', '啓幕', '女團', '打法', '攻略', '助力', '俗話', '牆', '人類', '卡', '正賽', '目標', '雪', '能源', '水墨石林', '創意', '飼料', '方案', '價值', '話題', '因素', '龍主', '里皮', '入圍賽', '高地', '素質', '光棍', '電商', '秀', '花式', '局面', '話', '物品', '潛質', '代表', '團體', '小學生', '偉人']
# =======================
# COLONCATEGORY : [':', '：']
# =======================
# Nc : ['寶閣', '湄潭縣', '球館', '家', '茂陵', '英', '旗下', '九寨', '塞班', '京東', '王者局', '閬', '楚河', '珠寶店', '吉爾吉斯斯坦', '廣安', '陸橋山', '黃鶴樓', '馬略卡島', '法國', '手游', '火山口', '火車站', '家地', '南陽', '淡路島', '潛江', '深海', '幽鶴', '高校', '合陽縣', '交界', '央行', '川藏', '孟津', '遵義市', '體育場', '侗寨', '城鎮', '唐人街', '珠海', '盧氏縣', '雪鄉', '阿拉德', '荒野', '西藏', '廣東', '唐山', '大連', '工信部', '湘西', '麥當勞', '電競站', '延邊', '浙里', '湖州', '山西', '冰城', '深圳', '湖北', '燴面店', '濟南', '銀川', '意大利', '轄區', '保監會', '天堂', '遼寧省', '央視', '水果店', '安居區', '火鍋店', '博物館', '牛場', '開灤', '歐洲', '海景驛站', '後座', '俄羅斯', '全球', '港交所', '本土', '邊緣', '雲端', '朝邑鎮', '下轄縣', '貴陽市', '保級區', '家鄉', '月亮灣', '皖南', '霞飛', '天際', '萊茵河', '股市', '日照市', '月季園', '產地', '萊加內斯', '宅']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['分紅', '抓來', '開戰', '退款', '鋪平', '騙錢', '罵屌絲', '鍍金', '解密', '提前', '再見', '加起來', '解圍', '加冕', '融資', '收回來', '領銜', '充飢', '退改', '解體', '執教', '站台', '通話', '扣分', '分組', '解惑', '加油', '加持', '定位', '效力', '導航', '一網打盡', '護航', '應對', '計算出來', '罰款', '助威', '分段', '入賬', '復仇', '拍照', '加工', '相比', '上架', '代打', '退貨', '充氣']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['不再', '需', '會不會', '親身', '快', '均', '不要', '突然', '去', '即', '必然', '接著', '正在', '連續', '更', '沒', '屢次', '始', '已然', '隨時', '永', '總', '多多', '私', '依舊', '預先', '所', '好在', '絕', '亂', '立即', '將', '可否', '大規模', '如何', '陸續', '能', '已', '還是', '反野', '真', '必須', '從', '盡快', '偶爾', '卻', '經常', '趁早', '不可以', '微', '逐漸', '竟然', '當下', '哈哈', '難以', '簡直', '獨', '略', '只是', '重新', '及時', '居然', '親自', '趕緊', '該不該', '一起', '互', '反', '一般', '終於', '相', '早', '正', '自然', '攜手', '總會', '急劇', '來', '變相', '並', '一手', '首先', '曾經', '同', '帶頭', '必', '大都', '不應該', '再度', '冒死', '呼好', '未', '無法', '大幅', '為什麼', '到底', '甚至', '隨', '聯合', '搞不好']
# =======================
# P : ['靠', '比如', '等', '按', '對', '趁', '自從', '比', '待', '除了', '被', '像', '如', '向', '憑', '離', '在', '趁著', '臨', '給', '為', '為了', '針對', '除', '慘遭', '自', '因', '把', '隨', '至', '受', '於', '和', '以', '幫', '跟', '將', '繼', '就', '隨了', '用', '往', '當', '關於', '根據', '與', '從', '直至', '到', '距離', '遭']
# =======================
# VG : ['理解為', '當作', '成', '稱作', '合成', '賣成', '改造成', '成為', '名叫', '堪稱', '如', '像', '排', '排名', '屈居', '叫', '投票成', '為', '做', '評選', '應聘', '美成', '稱得上', '算', '當上', '戰成', '充當', '類似', '居', '變成', '稱為', '化', '酷似', '集成', '誤認成', '彷彿', '當', '似', '並列', '非', '竟是', '建成', '算是', '叫做', '當成', '排行', '屬於', '譽為', '形成', '等於', '猶如', '變', '疑似', '稱', '姓', '升任', '封號', '作為', '做成']
# =======================
# Neu : ['4.5億', '600', '50多', '00', '500萬', '47億', '2018.5.6', '72', '三', '5050', '30萬', '37', '第9', '2', '8', '20萬一', '六', '百億', '1300', '600億', '17', '第十四', '120', '1', '第36', '300', '二十', '5.7', '6.9', '980', '十多萬', '九', '30', '8萬', '1299', '30000億', '1200億', '450億', '135', '13', '36萬', '兩', '10', '五', '三百', '：76', '1688', '38', '第一', '7億', '3:0', '42', '一萬', '千', '幾', '，0', '十萬', '4', ' 360', '一百', '60多', '二', '十億', '4G+64', '56', '70萬', '11.59億', '11', '0', '4000萬', '9-1', '21', '392億', '二〇三', '2.93億', '2:1', '115', '15', '十', '！2018', '5.5', '20億', '11億', '十五萬', '6800', '20萬', '第二', '40', '23萬一', '幾百', '47', '1.8億', '三千億', '第1', '2018', '四', '58', '730萬', '10萬', '2:3']
# =======================
# Nf : ['週', '分鐘', '畝', '方', '家', '部', '度', '頓', '噸', '步', '些', '日', '檔', '串', '晚', '招', '斤', '處', '期', '棵', '塊', '類', '碗', '位', '所', '層', '級', '點', '屆', '輪', 'K', '米', '天', '則', '回', '筆', '分', '場', '隻', '毛', '刻', '篇', '班', '盤', '把', '美元', '年', '頭', '公里', '票', '戶', '槍', '本', '股', '道', '掛', '株', '色', '件', '頁', '周', '元', '樣', '張', '節', '秒', '只', '遍', '局', '關', '號', '路', '座', '門', '番', '鍋', '袋', '港元', '群', '行', '胎', '對', '句', '支', '口', '台', '英吋', '條', '歲', '次', '套', '批', '輛', '名', '項', '隊', '款', '片', '種', '個']
# =======================
# VJ : ['抗', '從事', '受到', '欣賞', '看好', '翻倍', '輸掉', '強過', '負', '偏愛', '痛失', '耗', '沒', '達', '緊缺', '降至', '羨慕', '贊同', '達到', '獨佔', '受', '恪守', '歸', '來自', '毫無', '僅次於', '出身', '充', '入選', '不理', '惹不起', '爆發', '冷落', '分享', '晉級', '沈迷', '發揮', '領先', '看懂', '虧損', '平', '失', '含有', '經歷', '蘊藏', '歡迎', '值', '替代', '不如', '僅次', '過完', '透', '限', '近', '入圍', '出於', '賽', '連接', '負於', '曬', '持有', '吸引', '年入', '遺傳', '得', '靠', '適用', '贏下', '不敵', '缺', '缺少', '忽略', '關注', '出', '贏得', '逾', '養有', '自有', '喪失', '認', '忘懷', '共享', '為', '遭遇', '曝限', '維持', '發生', '嫌棄', '震撼到', '懷念', '衝', '脫', '納入', '超過', '要價', '適應', '不到', '失去', '新增', '共有']
# =======================
# VD : ['白送', '寄予', '支付', '發放', '分', '輸', '收費', '借貸', '貸', '坑', '予', '送', '給', '配', '借', '貸款', '傳', '補貼', '供應', '禁售', '清繳', '提供', '給予', '郵給', '發', '補繳', '還', '搶', '輸給', '付', '贏', '賣', '轉讓', '速遞', '售', '拒賠', '發給', '欠', '交付']
# =======================
# Dfa : ['過於', '遠', '十分', '多', '有點', '遠遠', '極', '好', '如此', '有些', '較', '更', '太', '更為', '比較', '不大', '最', '越來越', '過', '頗', '同樣', '還要', '還', '很', '超', '非常', '這麼']
# =======================
# VH : ['免息', '相對', '過多', '投機', '負', '穿', '百出', '驚人', '常用', '美味', '相應', '清淡', '失敗', '尷尬', '樂享', '多多', '爭相鬥艷', '豪華', '平均', '極好', '凝重', '神奇', '酷', '收場', '多姿', '適合', '不少', '摸不透', '落單', '致富', '變', '相生', '系統', '完整', '夠', '遠', '狂野', '低', '發熱', '窘', '粉', '乾淨', '濕潤', '小小', '簡約', '厲害', '分夠', '偏遠', '有錢', '重要', '機智', '逼格', '危險', '近', '掉', '深', '生猛', '成功', '絕殺', '完好', '不同', '這麼多', '迷路', '開通', '慘', '偉大', '長', '滿滿', '卡', '盡如人意', '浪漫', '實惠', '健康', '吉大利', '出線', '公正', '深入', '潰敗', '慘敗', '亮眼', '高速', '眾包', '傳統', '風光', '次輪', '不當', '相反', '好', '虛', '變差', '平庸', '秀', '那麼多', '衛生', '真不少', '炫酷', '暴', '有情', '鬼斧神工', '悲觀']
# =======================
# Cbb : ['而是', '如果', '還不如', '只要', '若', '而', '但是', '並', '不如', '即使', '並且', '縱使', '就算', '因', '連', '既', '反而', '否則', '雖然', '因為', '另外', '可是', '不僅', '但', '跟著', '不過', '要是', '假如', '不然', '只有', '不管', '既然']
# =======================
# Nd : ['春天', '4月', '週一', '中期', '夏窗', '一下', '採摘節', '5月份', '現代', '1日', '幾月份', '長期', '六', '2018年', '2005年', '目前', '5號', '週二', '晚清', '文化節', '四月', '秋季', '半夜', '5月', '31號', '5.7日', '23日', '季度', '旅遊節', '90年', '今天', '00年', '荒古', '週末', '大中', '短期', '同時', '10點', '未來', '明', '-5', '立夏', '初夏', '五月份', '夏', '明日', '晚間', '何時', '昨天', '8日', '旺季', '近日', '春季', '15日', '2018', '1990年', '下旬', '隔年', '過去', '如今', '小時候', '2017年', '相親節', '3月', '臨時', '季', '最近', '7號', '現在', '7日', '今夏', '明年', '8月', '秋', '13點', '一大早', '周', '中旬', '不久', '月季', '5日', '狗年', '6月', '夜', '30號', '6旬', '花季', '後', '2020年', '2019', '一會', '2035年', '6日', '米節', '九月', '夏日', '正月', '今年', '06日', '當年']
# =======================
# VA : ['代言', '出門', '保量', '開車', '娶妻', '歸來', '跪', '擾民', '鬥米', '進去', '表態', '理財', '格鬥', '申遺', '外出', '進貨', '續費', '就業', '掉幀', '釣魚', '生財', '答復', '募資', '犯規', '踏步', '換股', '脫坑', '日落', '下降', '領頭', '暴走', '見面', '點贊', '建功', '築底', '開盤', '加密', '倒計', '養花', '絕殺', '啓動', '潛伏', '壓槍', '成交', '出場', '砸盤', '開票', '卡', '升', '招商', '打卡', '蹲坑', '消失', '轉賬', '聊天', '坐', '探險', '旅遊', '輪轉', '出台', '出擊', '控股', '隨行', '徜徉', '下場', '喜極而泣', '唱空', '購物', '出欄', '倒地', '澆水', '字字珠璣', '助攻', '擺地攤', '抄底', '登高', '立刷', '發家', '刷單', '掃尾', '抗詹', '追肥', '徵信', '下山', '違規', '搶七', '買單', '相克', '入手', '掛牌', '開啓', '掙扎', '餵尿素', '看過來', '攻堅', '擒敵', '作證', '變陣', '大笑', '相約']
# =======================
# COMMACATEGORY : [',', '，']
# =======================
# Nes : ['首', '本', '頭', '近', '該', '前', '上', '何', '同', '每', '某', '貴', '後', '另', '下', '各']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# EXCLAMATIONCATEGORY : ['!', '！']
# =======================
# Di : ['起來', '過', '了', '個', '著']
# =======================
# Nep : ['那', '啥', '其', '其中', '哪', '這', '什麼', '此']
# =======================
# Caa : ['與', '到', '至', '或是', '和', '比', '或', '或者', '跟', '暨', 'VS', '又', '及', '還是']
# =======================
# VCL : ['暗渡', '用於', '深入', '進', '前來', '抵達', '路過', '回', '玩遍', '升至', '走到', '出', '去', '到達', '直達', '重回', '回歸', '遠離', '住', '前往', '走進', '在', '存進', '入', '遊覽', '橫掃', '穿越', '盤踞', '過', '栽進', '留在', '回到', '走過', '進入', '走下', '穿透', '走訪', '往', '來到', '登陸', '跌出', '重返', '到', '上', '度過', '退出', '出發到', '跌至', '穿過', '蒞臨', '赴']
# =======================
# Neqa : ['20%', '30%', '更多', '三分之一', '多', '80%', '個個', '多少', '很多', '一切', '12%', '百分之八十', '8%', '100%', '有些', '步步', '句句', '其它', '那些', '哪些', '部分', '10%', '大多', '41.8%', '無數', '大量', '任何', '滴滴', '9.89%', '一些', '遍', '15%', '半', '90%', '一點', '許多', '一半', '多點', '有的', '大多數', '四成', '一處處', '67%', '所有', '這麼多', '1/4', '0.8%', '不少', '1%', '其他', '6%', '全', '這些']
# =======================
# Nh : ['自身', '雙方', '各位', '小眾', '它', '別人', '你們', '它們', '私人', '誰', '他', '一方', '她們', '俺們', '屌絲', '我', '個人', '他們', '你', '她', '父子倆', '各自', '本人', '對方', '自我', '您', '自己', '大家', '我們', '人家']
# =======================
# FW : ['LOL：', 'lol', 'Ghappy', '+7', 'Minecraft', 'ABCC', 'Focus', 'IP', 'TT', 'iPhone X', 'XQ', 'MSI', 'CPI', 'TPP', 'iPhone7', '2', 'FW', 'CCR', 'Rookie', 'Guru', 'bad boy', 'U23', 'PPP', 'G', 'D', 'mix2', ' + ', 'DASH', 'LOL：MSI', 'mc', 'C', 'T', 'CP', 'SIo', ' 28', 'AIC', 'DNF', 'steam', 'CFO', '9A91', 'K', '6 10.5', 'vip', 'LOL', 'S11', 'LSPL', '4H', 'PS4/NS', 'numb', 'Nvidia', 'iBoy', 'Kitty', 'GoogleI/O2018', 'T+0', 'e', 'Soloking', 'VR ', 'kpl', 'dnf', '丨', '~', ' 2017', 'A', 'etc', 'HTC', 'FOF', 'msi', 'EOS', '4AM', 'KV', 'ipad', 'cba', 'Alan', 'EVO', '-6', 'iphone6plus', 'mAh+', ' 比', 'Credo', 'ios', 'OPPO R', '+', 'LPL', 'DNF ', 'ADC', '5A', 'OMG', 'ban', 'MSCI', 'Q', 'One', 'King James', 'wifi', 'N7', ' MDL', '6G+', 'pro7', 'J', 'FF ', 'DW']
# =======================
# SHI : ['是', '像是']
# =======================
# VE : ['討說', '證', '判定', '講解', '想要', '訴說', '以為', '爆料', '知詢', '見', '想', '呼', '算', '講', '見到', '問', '聊', '證明', '回顧', '告訴', '提醒', '判罰', '發誓', '警惕', '精准', '呼籲', '稱', '管', '預計', '形容', '商量', '估值', '見證', '確認', '公認', '承諾', '查', '幻想', '廣播', '聽到', '介紹', '猜', '樂見', '報道', '申卡', '禁止', '避免', '想起', '看出', '提猜', '示範', '說明', '限制', '防止', '識別', '揭曉', '炫耀', '准', '探索', '判斷', '聽說', '公告', '看看', '檢測', '聽', '想好', '假設', '查找', '說', '想到', '鑒定', '傳聞', '研究', '查看', '反對', '預期', '回答', '發現', '預告', '談', '披露', '設想', '探討', '允許', '提到', '考慮', '發佈', '認為', '看到', '聯想', '深思', '預防', '提', '要', '安排', '公示', '預測', '看清楚', '盛贊', '感嘆']
# =======================
# DE : ['得', '之', '的', '地']
# =======================
# VHC : ['產生', '優化', '縮小', '增長', '減少', '震驚', '感動', '斷', '現代化', '冷卻', '凍', '破', '還原', '恢復', '團結', '陷', '豐富', '傷', '停', '擴張', '降低', '平衡', '強化', '煩', '加快', '壞', '規模化', '溫暖', '下來', '辛苦', '暫停', '普及', '愁壞', '增加', '智能化', '熱', '肥', '愁死', '可憐', '穩定', '變動', '開', '增強', '麻煩', '結束', '機構化', '告破', '增 ', '滿足', '淡化', '國際化', '公開', '繁榮']
# =======================
# Ng : ['以外', '之上', '左右', '為止', '之中', '時', '之內', '以上', '外', '內', '起', '之外', '之間', '來', '初', '後', '以來', '下', '以後', '之下', '前', '般', '以下', '之後', '中', '底', '裡', '上', '之前', '而言', '間']
# =======================
# VK : ['流傳', '感謝', '肯定', '指望', '需', '確定', '意外', '奇怪', '盼', '顯示', '忘', '覺得', '懷疑', '曲解', '小心', '願', '恨', '理解', '感覺', '感受', '害怕', '所謂', '感覺到', '想見', '不滿', '同意', '恐', '願意', '討厭', '擔心', '需要', '期待', '遺憾', '不忘', '堅持', '怕', '遇', '瞭解', '放心', '意想不到', '懂得', '信', '忘記', '有利於', '懂', '希望', '知', '抱歉', '喜歡', '注意', '回憶', '覺', '面臨', '意味', '明白', '欲', '依賴', '知道', '介意']
# =======================
# Ncd : ['一帶', '底部', '方', '東部', '這裡', '中部', '東西部', '前沿', '外', '內', '那邊', '裡面', '西部', '西', '哪下', '哪', '下', '東', '以下', '末端', '哪裡', '東方', '邊', '上面', '中', '北', '哪兒', '外面', '上方', '裡', '上', '當中', '中間', '旁邊', '對面', '畔', '間', '那裡', '兩旁']
# =======================
# A : ['麻辣', '中西', '綜合', '小本', '歐式', '必備', '長途', '彩色', '同等', '一般', '現行', '地下', '基層', '碧藍', '大幅度', '重磅', '單', '乒乓', '高度', '上上', '原', '獨門', '最佳', '前置', '雙', '多餘', '總', '野生', '唯一', '常務', '優質', '共同', '火紅', '真正', '業餘', '新一代', '主', '中', '獨家', '額外', '非', '後置', '二手', '新興', '眾', '同一', '寶有', '超', '獨角', '基礎', '現役', '頭號', '國產', '超級']
# =======================
# V_2 : ['有']
# =======================
# VL : ['喜好', '不惜', '讓', '持續', '習慣', '使得', '愛好', '使', '趨於', '令', '愛', '用來', '致', '後悔', '敢', '開始', '能', '便利', '肯', '導致', '甘願', '故意']
# =======================
# T : ['嗎', '吧', '來', '了', '矣', '啊', '嘛', '的', '呢', '麼', '去', '哦', '啦', '哪', '咯']
# =======================
# VI : ['傾心', '驚艷', '取勝', '著稱', '專用']
# =======================
# DASHCATEGORY : ['-', '—']
# =======================
# I : ['哦', '瑪法里奧']
# =======================
# Dk : ['那', '結果', '那麼', '據說', '想不到', '外傳', '反過來', '據聞']
# =======================
# VF : ['圖', '申請', '要求', '逼', '試', '叫', '擬', '邀', '打算', '助', '勸說', '試試', '繼續', '判', '拒', '停止', '準備', '請', '止住', '拒絕', '率領', '催', '告誡', '鼓勵', '策劃', '勸住', '推選', '帶領']
# =======================
# Da : ['幾乎', '近', '幾近', '不下', '將近', '最多', '足足', '正好', '才', '約', '唯獨', '只', '僅', '光', '共']
# =======================
# PARENTHESISCATEGORY : ['（', '」', '(', '「', '）', '《', '》']
# =======================
# Nv : ['批發', '配置', '崩潰', '灌籃', '創業', '惡搞', '輔助', '防治', '回歸', '經歷', '旅遊', '射擊', '關聯', '登山', '航海', '私募', '推薦', '買單', '體驗', '翻譯', '燃燒', '組合', '增發', '研究', '管理', '代理', '護髮', '訴訟', '錄制', '度假', '抗戰', '分銷', '解救', '問', '遊樂', '銷售', '思考', '絕殺', '開發', '判罰', '供電', '兼職', '疊加', '營銷', '工作', '生產']
# =======================
# PERIODCATEGORY : ['。', '·']
# =======================
# VAC : ['蒸發', '推進', '移動', '動', '集合', '上演']
# =======================
# Dfb : ['極了', '些', '一點']
# =======================
# Cab : ['等等', '等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['幾', '以上', '半', '多']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
        # YOUR CODE HERE
        'Nh', 'Nep', 'Nes', 'DE', 'T', 'P', 'V_2', 'SHI',
        'Dfa', 'Dfb', 'Da', 'Di', 'Dk',
        'Caa', 'Cab', 'Cba', 'Cbb',
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 'ETCCATEGORY', 'EXCLAMATIONCATEGORY',
        'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY', 'SEMICOLONCATEGORY',
        'SPCHANGECATEGORY', 'WHITESPACE'
        # END YOUR CODE
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
def cosine_similarity(bow1, bow2):
    # YOUR CODE HERE
    len_bow1 = np.sqrt(np.sum(np.square(bow1)))
    len_bow2 = np.sqrt(np.sum(np.square(bow2)))
    similarity = np.sum(bow1 * bow2) / (len_bow1 * len_bow2)
    # END YOUR CODE
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333]),
#  '體育': array([0.04      , 0.01333333, 0.00333333, ..., 0.        , 0.        ,
#         0.        ])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 73, '遊戲': 8, '財經': 6, '旅遊': 6, '農業': 6, '科技': 3})
# predict 財經 :  Counter({'財經': 67, '科技': 18, '體育': 6, '旅遊': 6, '遊戲': 6, '農業': 5})
# predict 科技 :  Counter({'科技': 62, '財經': 13, '體育': 10, '農業': 6, '遊戲': 6, '旅遊': 2})
# predict 旅遊 :  Counter({'旅遊': 70, '農業': 11, '財經': 6, '科技': 3, '遊戲': 2})
# predict 農業 :  Counter({'農業': 70, '旅遊': 9, '科技': 6, '體育': 5, '財經': 4, '遊戲': 3})
# predict 遊戲 :  Counter({'遊戲': 75, '科技': 7, '旅遊': 5, '體育': 4, '財經': 4, '農業': 1})
